# %% [markdown]
# # Importing Libraries

# %%
pip install --user opencv-contrib-python
# Out:
# ...
#      ---------------------------------------- 44.9/44.9 MB 9.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Reading Image

# %%
img = cv2.imread('TOM.JPG')

# %% [markdown]
# # Colour Conversion

# %%
rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %% [markdown]
# # Scale Invariance

# %%
TOM = cv2.pyrDown(rgb)
TOM1 = cv2.pyrDown(sc_iv)
num_rows, num_cols = TOM.shape[:2]
print(TOM)
# Out:
# [[[237 132 198]
#   [237 132 198]
#   [237 132 198]
#   ...
#   [237 132 198]
#   [237 132 198]
#   [237 132 198]]
#
#  [[237 132 198]
#   [237 132 198]
#   [237 132 198]
#   ...
#   [237 132 198]
#   [237 132 198]
#   [237 132 198]]
#
#  [[237 132 198]
#   [237 132 198]
#   [237 132 198]
#   ...
#   [237 132 198]
#   [237 132 198]
#   [237 132 198]]
#
#  ...
#
#  [[237 132 198]
#   [237 132 198]
#   [237 132 198]
#   ...
#   [237 132 198]
#   [237 132 198]
#   [237 132 198]]
#
#  [[237 132 198]
#   [237 132 198]
#   [237 132 198]
#   ...
#   [237 132 198]
#   [237 132 198]
#   [237 132 198]]
#
#  [[237 132 198]
#   [237 132 198]
#   [237 132 198]
#   ...
#   [237 132 198]
#   [237 132 198]
#   [237 132 198]]]

# %%
cv2.imshow("TOM",img)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imshow("first scale",TOM)
cv2.waitKey(0)
cv2.destroyAllWindows()
cv2.imshow("secon scale",TOM1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Rotational Invariance

# %%
rot_iv=cv2.getRotationMatrix2D((num_cols/2,num_rows/2),90,0.5)

# %% [markdown]
# # Affine Transformation

# %%
aff=cv2.warpAffine(TOM,rot_iv,(num_cols,num_rows))

# %% [markdown]
# # Color Convertion

# %%
rot_gray = cv2.cvtColor(aff, cv2.COLOR_RGB2GRAY)

# %% [markdown]
# # Rotational Display

# %%
fx, plots = plt.subplots(1, 2, figsize=(20,10))

plots[0].set_title("Training Image")
plots[0].imshow(rgb)

plots[1].set_title("Testing Image")
plots[1].imshow(aff)

# %% [markdown]
# # SIFT

# %%
sift = cv2.xfeatures2d.SIFT_create()
