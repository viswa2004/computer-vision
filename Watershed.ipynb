# %% [markdown]
# # Importing library

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Reading in image

# %%
img = cv2.imread("b3_final.webp")
cv2.imshow("IMAGE",img)
cv2.waitKey(0)
# Out:
# -1

# %% [markdown]
# # Converting to gray scale

# %%
img_RBG = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
img_gray=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)
plt.imshow(img_gray)

# %% [markdown]
# # Image Thresholding

# %%
img1m = cv2.medianBlur(img_gray,1)
#ret,th1 = cv2.threshold(img1m,100,255,cv2.THRESH_BINARY)
ath1 = cv2.adaptiveThreshold(img1m,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,\
                            cv2.THRESH_BINARY,141,5)
plt.imshow(ath1)

# %% [markdown]
# # Noise

# %%
Kernel = np.ones((3,3),np.uint8)
opening = cv2.morphologyEx(ath1,cv2.MORPH_OPEN,Kernel,iterations=5)
plt.imshow(opening)

# %% [markdown]
# # Sure background

# %%
sure_bg=cv2.dilate(opening,Kernel,iterations=5)
plt.imshow(sure_bg)
